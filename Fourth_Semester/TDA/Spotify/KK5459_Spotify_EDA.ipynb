# %%
import pandas as pd
import json
import glob

# %%
file_paths=glob.glob("Streaming_History_Audio_*.json")

#Combine all JSON files

combined_data = []
for path in file_paths:
    with open(path,'r', encoding='utf-8') as f:
        data = json.load(f)
        combined_data.extend(data)


#Convert to DataFrame
df = pd.DataFrame(combined_data)

#Preview
df_sample = df.head(5)
df_info = df.info()
missing_values = df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120436 entries, 0 to 120435
# Data columns (total 23 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   ts                                 120436 non-null  object
#  1   platform                           120436 non-null  object
#  2   ms_played                          120436 non-null  int64
#  3   conn_country                       120436 non-null  object
#  4   ip_addr                            120436 non-null  object
#  5   master_metadata_track_name         119898 non-null  object
#  6   master_metadata_album_artist_name  119898 non-null  object
#  7   master_metadata_album_album_name   119898 non-null  object
#  8   spotify_track_uri                  119898 non-null  object
#  9   episode_name                       538 non-null     object
#  10  episode_show_name                  538 non-null     object
#  11  spotify_episode_uri                538 non-null     object
#  12  audiobook_title                    0 non-null       object
#  13  audiobook_uri                      0 non-null       object
#  14  audiobook_chapter_uri              0 non-null       object
#  15  audiobook_chapter_title            0 non-null       object
#  16  reason_start                       120436 non-null  object
#  17  reason_end                         120436 non-null  object
#  18  shuffle                            120436 non-null  bool
#  19  skipped                            120436 non-null  bool
#  20  offline                            120436 non-null  bool
#  21  offline_timestamp                  58403 non-null   float64
#  22  incognito_mode                     120436 non-null  bool
# dtypes: bool(4), float64(1), int64(1), object(17)
# memory usage: 17.9+ MB

# %%
df_sample
# Out:
#                      ts               platform  ms_played conn_country  \
# 0  2018-09-24T05:03:22Z  iOS 12.0 (iPhone10,3)     104938           PE
# 1  2018-09-24T05:05:44Z  iOS 12.0 (iPhone10,3)     140217           PE
# 2  2018-09-24T05:06:13Z  iOS 12.0 (iPhone10,3)      27837           PE
# 3  2018-09-24T05:09:18Z  iOS 12.0 (iPhone10,3)     184768           PE
# 4  2018-09-24T05:12:12Z  iOS 12.0 (iPhone10,3)     174489           PE
#
#           ip_addr master_metadata_track_name  \
# 0  190.113.214.19                       idfc
# 1  190.113.214.19                       idfc
# 2  190.113.214.19         idfc (Tarro Remix)
# 3  190.113.214.19                       Idfc
# 4  190.113.214.19    Floating (feat. Khalid)
#
#   master_metadata_album_artist_name master_metadata_album_album_name  \
# 0                         blackbear                        deadroses
# 1                         blackbear                        deadroses
# 2                         blackbear               idfc (Tarro Remix)
# 3                      high on you.                             Idfc
# 4                       Alina Baraz                 The Color Of You
#
#                       spotify_track_uri episode_name  ... audiobook_uri  \
# 0  spotify:track:6y6jbcPG4Yn3Du4moXaenr         None  ...          None
# 1  spotify:track:6y6jbcPG4Yn3Du4moXaenr         None  ...          None
# 2  spotify:track:44UQpKpI54KOZLAFaDAr9X         None  ...          None
# 3  spotify:track:6FAi5DFwIVcum4NadHVk0c         None  ...          None
# 4  spotify:track:2vLWF4yFhTHQZVwrPTjH1s         None  ...          None
#
#   audiobook_chapter_uri audiobook_chapter_title reason_start  \
# 0                  None                    None     clickrow
# 1                  None                    None      appload
# 2                  None                    None    trackdone
# 3                  None                    None     clickrow
# 4                  None                    None     clickrow
#
#                      reason_end shuffle skipped offline  offline_timestamp  \
# 0  unexpected-exit-while-paused   False   False   False                NaN
# 1                     trackdone   False   False   False                NaN
# 2                       endplay   False   False   False                NaN
# 3                       endplay   False   False   False                NaN
# 4                     trackdone    True   False   False                NaN
#
#    incognito_mode
# 0           False
# 1           False
# 2           False
# 3           False
# 4           False
#
# [5 rows x 23 columns]
